# %%
import pandas as pd

bucket='winhybridation-dev-24-07-s3b3h6cv-1v81fpftd00kn'
data_key = 'hpcaccess2.log'
data_location = 's3://winhybridation-dev-24-07-s3b3h6cv-1v81fpftd00kn/hpcaccess2.log'.format(bucket, data_key)


pd.read_csv(data_location, sep=' ')
# Out:
#        2  3656267309-67309365627912244327879022  cp-1  origin-39  \
# 0      2   9407592454-9245494075214801485679000  cp-2  origin-43
# 1      2    238342574-4257423831961691166201570  cp-2   origin-1
# 2      2    882945378-5378882948940783476312183  cp-1  origin-19
# 3      2  1346962158-62158134691982420844847507  cp-1  origin-35
# 4      2  1389931489-31489138993118143112324705  cp-1  origin-47
# ...   ..                                    ...   ...        ...
# 20668  2    775136486-6486775131536322946004114  cp-2  origin-20
# 20669  2  2079630775-30775207963632786363392208  cp-2  origin-47
# 20670  2   9999482916-8291699994105455876228405  cp-1  origin-44
# 20671  2  9466964657-64657946692194861443472501  cp-2  origin-41
# 20672  2  7677463230-63230767747728240496941767  cp-1  origin-12
#
#        cdnprefix-11  cdnprefix-11-host   node-6  site5  \
# 0       cdnprefix-5   cdnprefix-5-host  node-12  site5
# 1       cdnprefix-4   cdnprefix-4-host  node-17  site1
# ...
